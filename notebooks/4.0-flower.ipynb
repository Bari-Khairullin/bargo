# %%
import sys
sys.path.append('../')

import tensorflow as tf
import bargo.datasets as datasets
import bargo.engine as engine
import bargo.utils as utils
import numpy as np
import matplotlib.pyplot as plt

import logging
import pickle

logging.getLogger("tensorflow").setLevel(logging.ERROR)
# Out:
# 2024-03-31 17:06:13.130263: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
n = 2000
X = datasets.rectangle(n, 2, 2)
# X = datasets.circle(n, 1)
# Y = datasets.elephant(n, 2, 0.5)
Y = datasets.flower(n, 1, 0.2, 5) * 1.2
Y -= Y.mean(axis=0)
grid = {'x0': -1, 'x1': 1, 'dx': 0.025, 'y0': -1, 'y1': 1, 'dy': 0.025}
grid = datasets.flat_grid(**grid)
fig, ax = utils.scatter([('Coordinate boundary', X), ('Physical boundary', Y)], grid, figsize=(7, 7))

# %%
N = 10
a = 1
h = 2 * a / (N - 1)

mesh = []
mask = []
for i in range(N):
    for j in range(N):
        x = -a + i * h
        y = -a + j * h
        if not (i==0 or j==0 or i==N-1 or j==N-1):
            mesh.append([x, y])
        mask.append(not (i==0 or j==0 or i==N-1 or j==N-1))

mask = np.reshape(mask, (N, N))
# with open('data/run13/N40/mask.pkl', 'wb') as f:
#     pickle.dump(mask, f)

# %%
class abs_leq1(tf.keras.constraints.Constraint):
    def __init__(self, dl) -> None:
        super().__init__()
        self.dl = dl
        pass
    def __call__(self, w):
        while True:
            test_value = self.dl * tf.abs(tf.linalg.trace(w)) + self.dl**2 * tf.abs(tf.linalg.det(w))
            if test_value < 1 - 1e-1:
                return w
            else:
                w = w / 1.1

class geq0(tf.keras.constraints.Constraint):
    def __init__(self, dl) -> None:
        super().__init__()
        self.dl = dl
        pass
    def __call__(self, w):
        if (tf.linalg.trace(w) < 0) or (tf.linalg.det(w) < 0):
            w = tf.abs(w)
            w = w * tf.constant([[1., -1.], [1., 1.]])
        return w
    
class grad(tf.keras.constraints.Constraint):
    def __init__(self, dl, alpha=0.01) -> None:
        super().__init__()
        self.dl = dl
        self.alpha = alpha
        pass

    # def test_f(self, w00, w01, w10, w11):
    #         return 2*self.dl*(tf.abs(w00)+tf.abs(w11))+self.dl**2*(w00*w11-w01*w10)
    # def graf_f(self, w00, w01, w10, w11):
    #     grad00 = 2*self.dl*tf.sign(w00)+self.dl**2*w11
    #     grad01 = -self.dl**2*w10
    #     grad10 = -self.dl**2*w01
    #     grad11 = 2*self.dl*tf.sign(w11)+self.dl**2*w00
    #     return tf.constant([[grad00, grad01], [grad10, grad11]])
    
    def test_f(self, w00, w01, w10, w11):
        dl = self.dl
        detW = w00*w11-w01*w10
        H = (tf.sign(detW) + 1) / 2
        return dl*tf.sqrt(2*tf.square(w00)+2*tf.square(w11))-dl**2*H*detW
    def grad_f(self, w00, w01, w10, w11):
        dl = self.dl
        detW = w00*w11-w01*w10
        H = (tf.sign(detW) + 1) / 2
        grad00 = dl*w00*tf.sqrt(2/(tf.square(w00)+tf.square(w11)))-dl**2*H*w11
        grad01 = self.dl**2*H*w10
        grad10 = self.dl**2*H*w01
        grad11 = dl*w11*tf.sqrt(2/(tf.square(w00)+tf.square(w11)))-dl**2*H*w00
        return tf.Variable([[grad00, grad01], [grad10, grad11]])

    def get_wij(self, w):
        w00 = tf.reduce_sum(w * tf.constant([[1., 0], [0, 0]]))
        w01 = tf.reduce_sum(w * tf.constant([[0, 1.], [0, 0]]))
        w10 = tf.reduce_sum(w * tf.constant([[0, 0], [1., 0]]))
        w11 = tf.reduce_sum(w * tf.constant([[0, 0], [0, 1.]]))
        return w00, w01, w10, w11
    
    def __call__(self, w):
        count = 0
        alpha = self.alpha
        wij = self.get_wij(w)
        while (self.test_f(*wij)) > 1:
            if count < 1000:
                w = w - alpha * self.grad_f(*wij)
                wij = self.get_wij(w)
            else:
                w = w / 1.1
                wij = self.get_wij(w)
        return w

# %%
n_hidden_layers = 30
C = 1
args_hidden = {
    'units': 2,
    'activation': 'tanh',
    'kernel_initializer': 'zeros',
    'bias_initializer': 'zeros',
    # 'kernel_constraint': grad(1 / n_hidden_layers),
}
model = engine.NN.diffeomorphism(C=C, n_hidden_layers=n_hidden_layers, **args_hidden)
# Out:
# 2024-03-31 17:06:15.743091: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-31 17:06:15.744099: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2024-03-31 17:06:15.767339: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.767622: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 30 deviceMemorySize: 5.78GiB deviceMemoryBandwidth: 312.97GiB/s
# 2024-03-31 17:06:15.767651: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-31 17:06:15.769708: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-31 17:06:15.769808: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-31 17:06:15.771393: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-31 17:06:15.771798: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-31 17:06:15.773942: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-31 17:06:15.775117: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-31 17:06:15.779314: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-31 17:06:15.779591: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.779944: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.780141: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-31 17:06:15.780480: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-31 17:06:15.781703: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2024-03-31 17:06:15.781914: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.782143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:07:00.0 name: NVIDIA GeForce RTX 2060 computeCapability: 7.5
# coreClock: 1.83GHz coreCount: 30 deviceMemorySize: 5.78GiB deviceMemoryBandwidth: 312.97GiB/s
# 2024-03-31 17:06:15.782176: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-31 17:06:15.782216: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2024-03-31 17:06:15.782231: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2024-03-31 17:06:15.782245: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2024-03-31 17:06:15.782259: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2024-03-31 17:06:15.782273: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2024-03-31 17:06:15.782288: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2024-03-31 17:06:15.782302: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2024-03-31 17:06:15.782373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.782598: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:15.782762: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2024-03-31 17:06:15.782795: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2024-03-31 17:06:16.381455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2024-03-31 17:06:16.381496: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2024-03-31 17:06:16.381505: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2024-03-31 17:06:16.381765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:16.382003: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:16.382212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2024-03-31 17:06:16.382380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 4975 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060, pci bus id: 0000:07:00.0, compute capability: 7.5)

# %%
trainer = engine.Trainer(model)
trainer.prepare_data(X, Y, 0.2, 0.2, mesh, grid)

# %%
trainer.opt = tf.keras.optimizers.Adam(learning_rate=0.1)
# trainer.loss_fn = engine.CustomLoss(boundary_loss='mse', mesh_loss='winslow', eps=1e-1)
trainer.loss_fn = engine.CustomLoss(boundary_loss='abs_distance')

# %%
trainer.fit(epochs=1000000, patience=1000, val_boundary_loss_target=1e-9, decay_patience=None, plot_step=1000)
# Out:
#   0%|          | 0/1000000 [00:00<?, ?it/s]2024-03-31 17:06:16.798064: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# train_loss: 1.9477e-01 val_boundary_loss: 1.9207e-01 eps: 1e+00:   0%|          | 38/1000000 [00:02<19:25:36, 14.30it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_64723/1087053255.py in <module>
# ----> 1 trainer.fit(epochs=1000000, patience=1000, val_boundary_loss_target=1e-9, decay_patience=None, plot_step=1000)
#
# ~/Desktop/diploma/bargo/engine.py in fit(self, epochs, patience, val_boundary_loss_target, decay_patience, plot_step)
#     387
#     388         for epoch in pbar:
# --> 389             train_loss_value = self.train_step(self.X_train, self.Y_train, self.meshX)
#     390             val_boundary_loss_value = self.eval_boundary(self.X_val, self.Y_val)
#     391
#
# ~/Desktop/diploma/bargo/engine.py in train_step(self, X_train, Y_train, meshX)
#     345             else:
#     346                 Js = None
# --> 347             Y_train_pred = self.model(X_train)
#     348             loss = self.loss_fn(Y_true=Y_train, Y_pred=Y_train_pred, Js=Js)
#     349
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     423     """
#     424     return self._run_internal_graph(
# --> 425         inputs, training=training, mask=mask)
#     426
#     427   def compute_output_shape(self, input_shape):
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     558
#     559         args, kwargs = node.map_arguments(tensor_dict)
# --> 560         outputs = node.layer(*args, **kwargs)
#     561
#     562         # Update tensor_dict.
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py in _call_wrapper(*args, **kwargs)
#    1325     # Decorate the function to produce this layer's call method
#    1326     def _call_wrapper(*args, **kwargs):
# -> 1327       return self._call_wrapper(*args, **kwargs)
#    1328     self.call = tf_decorator.make_decorator(function, _call_wrapper)
#    1329
#
# ~/miniconda3/envs/bargo/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py in _call_wrapper(self, *args, **kwargs)
#    1356       # `name` passed (which is susceptible to producing
#    1357       # multiple ops w/ the same name when the layer is reused)
# -> 1358       kwargs.pop('name', None)
#    1359       result = self.function(*args, **kwargs)
#    1360     self._check_variables(created_variables, tape.watched_variables())
#
# KeyboardInterrupt:

# %% [markdown]
# from scipy import interpolate

# %% [markdown]
# fun = interpolate.LinearNDInterpolator(X, Y)

# %% [markdown]
# fun = interpolate.CloughTocher2DInterpolator(X, Y, maxiter=1000, tol=1e-8)

# %% [markdown]
# xf = interpolate.interp2d(X[:, 0], X[:, 1], Y[:, 0], kind='cubic')

# %% [markdown]
# yf = interpolate.interp2d(X[:, 0], X[:, 1], Y[:, 1], kind='cubic')

# %% [markdown]
# deformed_grid = []
# for line in grid:
#     deformed_grid.append([])
#     for pt in line:
#         deformed_grid[-1].append([xf(*pt), yf(*pt)])

# %% [markdown]
# deformed_grid = []
# for line in grid:
#     deformed_grid.append(fun(line))

# %% [markdown]
# Y_pred = fun(X)

# %% [markdown]
# fig, ax = utils.scatter([('Coordinate boundary', Y_pred), ('Physical boundary', Y)], deformed_grid, figsize=(7, 7))

# %% [markdown]
# model.save('data/run13/model.keras')

# %% [markdown]
# engine.Geometry.push_forward(mesh, 'data/run13/N40')
